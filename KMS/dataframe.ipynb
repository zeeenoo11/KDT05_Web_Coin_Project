# %%
import pandas as pd
import cudf
from sqlalchemy import create_engine, Connection, text

# %%
engine = create_engine('mysql+pymysql://root:kdt5@localhost:3306/Team2?charset=utf8mb4')

# %%
with engine.begin() as conn:
    df = pd.read_sql(text('SELECT * FROM BTCUSDT_1m'), conn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df = pd.read_sql(text('SELECT * FROM BTCUSDT_1m'), engine)
#
# File /media/data/miniconda3/envs/EXAM_DL/lib/python3.9/site-packages/pandas/io/sql.py:590, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     581     return pandas_sql.read_table(
#     582         sql,
#     583         index_col=index_col,
#    (...)
#     587         chunksize=chunksize,
#     588     )
#     589 else:
# --> 590     return pandas_sql.read_query(
#     591         sql,
#     592         index_col=index_col,
#     593         params=params,
#     594         coerce_float=coerce_float,
#     595         parse_dates=parse_dates,
#     596         chunksize=chunksize,
#     597     )
#
# ...
