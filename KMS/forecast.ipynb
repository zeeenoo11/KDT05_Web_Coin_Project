# %%
# !pip install torch torchvision torchaudio
# !pip install pytorch-forecasting
# !pip install requests
# !pip install fastparquet
# !pip install --no-cache --force optuna==3.4.0 torch==2.1.0
# !pip install --no-cache --force torch==2.0.1 pytorch-lightning==2.0.2 pytorch_forecasting==1.0.0 torchaudio==2.0.2 torchdata==0.6.1 torchtext==0.15.2 torchvision==0.15.2 optuna==3.4
# !pip install torchmetrics

# %%
import os
import warnings

warnings.filterwarnings("ignore")

# %%
import copy
from pathlib import Path
import warnings

import lightning.pytorch as pl
from lightning.pytorch.callbacks import EarlyStopping, LearningRateMonitor
from lightning.pytorch.loggers import TensorBoardLogger
import numpy as np
import pandas as pd
import torch
from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import MAE, SMAPE, QuantileLoss, PoissonLoss

# %%
from pytorch_forecasting.data.examples import get_stallion_data

data = get_stallion_data()

# %%
data['time_idx'] = data['date'].dt.year * 12 + data['date'].dt.month
data['time_idx'] -= data['time_idx'].min()

# %%
data['month'] = data.date.dt.month.astype(str).astype('category')
data['log_volume'] = np.log(data.volume + 1e-8)
data['avg_volume_by_sku'] = data.groupby(['time_idx', 'sku'], observed=True).volume.transform('mean')
data['avg_volume_by_agency'] = data.groupby(['time_idx', 'agency'], observed=True).volume.transform('mean')

# %%
# we want to encode special days as one variable and thus need to first reverse one-hot encoding
special_days = [
    "easter_day",
    "good_friday",
    "new_year",
    "christmas",
    "labor_day",
    "independence_day",
    "revolution_day_memorial",
    "regional_games",
    "fifa_u_17_world_cup",
    "football_gold_cup",
    "beer_capital",
    "music_fest",
]

data[special_days] = data[special_days].apply(lambda x: x.map({0: '-', 1: x.name})).astype('category')

# %%
data.sample(3)
# Out:
#           agency     sku    volume       date  industry_volume  soda_volume  \
# 6023   Agency_29  SKU_05   33.4836 2015-12-01        568138672    822672453
# 14708  Agency_18  SKU_01   12.7440 2015-06-01        549967070    899297932
# 3962   Agency_13  SKU_03  222.3288 2014-11-01        484133145    715784335
#
#        avg_max_temp  price_regular  price_actual    discount  ...  \
# 6023      29.893333    1892.610405   1731.752298  160.858107  ...
# 14708     32.109091    1337.375000   1237.062500  100.312500  ...
# 3962      22.787815    1410.535213   1303.939517  106.595696  ...
#
#        football_gold_cup  beer_capital music_fest discount_in_percent  \
# 6023                   -             -          -            8.499272
# 14708                  -             -          -            7.500701
# 3962                   -             -          -            7.557110
#
#       timeseries time_idx month log_volume avg_volume_by_sku  \
# 6023         175       35    12   3.511056       1676.262888
# 14708        139       29     6   2.545061       3423.014365
# 3962         277       22    11   5.404157       1425.826168
#
#       avg_volume_by_agency
# 6023             17.190643
# 14708           106.432920
# 3962           1722.444300
#
# [3 rows x 31 columns]

# %%
data.describe()
# Out:
#              volume                 date  industry_volume   soda_volume  \
# count  21000.000000                21000     2.100000e+04  2.100000e+04
# mean    1492.403982  2015-06-16 20:48:00     5.439214e+08  8.512000e+08
# min        0.000000  2013-01-01 00:00:00     4.130518e+08  6.964015e+08
# 25%        8.272388  2014-03-24 06:00:00     5.090553e+08  7.890880e+08
# 50%      158.436000  2015-06-16 00:00:00     5.512000e+08  8.649196e+08
# 75%     1774.793475  2016-09-08 12:00:00     5.893715e+08  9.005551e+08
# max    22526.610000  2017-12-01 00:00:00     6.700157e+08  1.049869e+09
# std     2711.496882                  NaN     6.288022e+07  7.824340e+07
#
#        avg_max_temp  price_regular  price_actual      discount  \
# count  21000.000000   21000.000000  21000.000000  21000.000000
# mean      28.612404    1451.536344   1267.347450    184.374146
# min       16.731034       0.000000  -3121.690141      0.000000
# 25%       25.374816    1311.547158   1178.365653     54.935108
# 50%       28.479272    1495.174592   1324.695705    138.307225
# 75%       31.568405    1725.652080   1517.311427    272.298630
# max       45.290476   19166.625000   4925.404000  19166.625000
# std        3.972833     683.362417    587.757323    257.469968
#
#        avg_population_2017  avg_yearly_household_income_2017  \
# count         2.100000e+04                      21000.000000
# mean          1.045065e+06                     151073.494286
# min           1.227100e+04                      90240.000000
# 25%           6.018900e+04                     110057.000000
# 50%           1.232242e+06                     131411.000000
# 75%           1.729177e+06                     206553.000000
# max           3.137874e+06                     247220.000000
# std           9.291926e+05                      50409.593114
#
#        discount_in_percent   timeseries      time_idx    log_volume  \
# count         21000.000000  21000.00000  21000.000000  21000.000000
# mean             10.574884    174.50000     29.500000      2.464118
# min               0.000000      0.00000      0.000000    -18.420681
# 25%               3.749628     87.00000     14.750000      2.112923
# 50%               8.948990    174.50000     29.500000      5.065351
# 75%              15.647058    262.00000     44.250000      7.481439
# max             226.740147    349.00000     59.000000     10.022453
# std               9.590813    101.03829     17.318515      8.178218
#
#        avg_volume_by_sku  avg_volume_by_agency
# count       21000.000000          21000.000000
# mean         1492.403982           1492.403982
# min             0.000000              0.000000
# 25%           932.285496            113.420250
# 50%          1402.305264           1730.529771
# 75%          2195.362302           2595.316500
# max          4332.363750           5884.717375
# std          1051.790829           1328.239698

# %%
max_prediction_length = 6
max_encoder_length = 24
training_cutoff = data['time_idx'].max() - max_prediction_length

training = TimeSeriesDataSet(
    data[lambda x: x.time_idx <= training_cutoff],
    time_idx = 'time_idx',
    target = 'volume',
    group_ids = ['agency', 'sku'],
    min_encoder_length=max_encoder_length // 2,
    max_encoder_length=max_encoder_length,
    min_prediction_length=1,
    max_prediction_length=max_prediction_length,
    static_categoricals=['agency', 'sku'],
    static_reals = ['avg_population_2017', 'avg_yearly_household_income_2017'],
    time_varying_known_categoricals=['special_days', 'month'],
    variable_groups = {
        'special_days': special_days,
    },
    time_varying_known_reals = ['time_idx', 'price_regular', 'discount_in_percent'],
    time_varying_unknown_categoricals=[],
    time_varying_unknown_reals = [
        "volume",
        "log_volume",
        "industry_volume",
        "soda_volume",
        "avg_max_temp",
        "avg_volume_by_agency",
        "avg_volume_by_sku",
    ],
    target_normalizer = GroupNormalizer(
        groups = ['agency', 'sku'], transformation = 'softplus'
    ),
    add_relative_time_idx = True,
    add_target_scales = True,
    add_encoder_length = True,
)

validation = TimeSeriesDataSet.from_dataset(training, data, predict=True, stop_randomization=True)

# %%
batch_size = 128
train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size * 10, num_workers=0)

# %%
baseline_predictions = Baseline().predict(val_dataloader, return_y=True)
MAE()(baseline_predictions.output, baseline_predictions.y)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA A100 80GB PCIe MIG 7g.80gb') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# tensor(293.0088, device='cuda:0')

# %%
pl.seed_everything(42)
trainer = pl.Trainer(
    accelerator='gpu',
    gradient_clip_val=0.1,
)
# Out:
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate = 0.03,
    hidden_size = 8,
    attention_head_size = 1,
    dropout = 0.1,
    hidden_continuous_size = 8,
    loss = QuantileLoss(),
    optimizer = "Ranger",
)

print(f'Number of parameters in network : {tft.size()/1e3:.1f}')
# Out:
# Number of parameters in network : 13.5

# %%
from lightning.pytorch.tuner import Tuner

res = Tuner(trainer).lr_find(
    tft,
    train_dataloaders = train_dataloader,
    val_dataloaders = val_dataloader,
    max_lr = 10.0,
    min_lr = 1e-6,
)

print(f"suggested learning rate : {res.suggestion()}")
fig = res.plot(show=True, suggest=True)
fig.show()
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Finding best initial lr:  99%|█████████▉| 99/100 [00:09<00:00, 10.19it/s]`Trainer.fit` stopped: `max_steps=100` reached.
# Finding best initial lr: 100%|██████████| 100/100 [00:09<00:00, 10.14it/s]
# Learning rate set to 0.12882495516931336
# Restoring states from the checkpoint path at /media/data/KDT_Binance/.lr_find_0d668022-ecd0-4743-9bd9-228d7f563897.ckpt
# Restored all states from the checkpoint at /media/data/KDT_Binance/.lr_find_0d668022-ecd0-4743-9bd9-228d7f563897.ckpt
# suggested learning rate : 0.12882495516931336

# %%
# !pip install -U 'tensorboard'

# %%
early_stop_callback = EarlyStopping(
    monitor='val_loss', 
    min_delta=1e-4, 
    patience=10, 
    verbose=False, 
    mode='min'
)

lr_logger = LearningRateMonitor()
logger = TensorBoardLogger('lightning_logs')

trainer = pl.Trainer(
    max_epochs=50,
    accelerator = 'cpu',
    enable_model_summary=True,
    gradient_clip_val=0.1,
    limit_train_batches=50,
    fast_dev_run=True,
    callbacks=[early_stop_callback, lr_logger],
    logger=logger,
)


tft = TemporalFusionTransformer.from_dataset(
    training,
    learning_rate = 0.03,
    hidden_size = 16,
    attention_head_size = 2,
    dropout = 0.1,
    hidden_continuous_size = 8,
    loss = QuantileLoss(),
    log_interval = 10,
    optimizer = "Ranger",
    reduce_on_plateau_patience = True,
)

print(f"Number of parameters in network : {tft.size()/1e3:.1f}")
# Out:
# GPU available: True (cuda), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Running in `fast_dev_run` mode: will run the requested loop using 1 batch(es). Logging and checkpointing is suppressed.
# Number of parameters in network : 29.4

# %%
trainer.fit(tft, train_dataloader, val_dataloaders=val_dataloader)
# Out:
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 1.3 K
# 3  | prescalers                         | ModuleDict                      | 256
# 4  | static_variable_selection          | VariableSelectionNetwork        | 3.4 K
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 8.0 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 2.7 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K
# 11 | lstm_encoder                       | LSTM                            | 2.2 K
# 12 | lstm_decoder                       | LSTM                            | 2.2 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 808
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576
# 20 | output_layer                       | Linear                          | 119
# ----------------------------------------------------------------------------------------
# 29.4 K    Trainable params
# 0         Non-trainable params
# 29.4 K    Total params
# 0.118     Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  1.56it/s, train_loss_step=289.0, val_loss=383.0, train_loss_epoch=289.0]
# `Trainer.fit` stopped: `max_steps=1` reached.
# Epoch 0: 100%|██████████| 1/1 [00:00<00:00,  1.56it/s, train_loss_step=289.0, val_loss=383.0, train_loss_epoch=289.0]

# %%
import pickle

from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

study = optimize_hyperparameters(
    train_dataloader,
    val_dataloader,
    model_path='optuna_test',
    n_trials = 10,
    max_epochs = 50,
    gradient_clip_val_range = (0.01, 1.0),
    hidden_size_range = (8, 128),
    hidden_continuous_size_range = (1, 4),
    learning_rate_range = (0.001, 0.1),
    dropout_range = (0.1, 0.3),
    trainer_kwargs = dict(limit_train_batches=30),
    reduce_on_plateau_patience = 4,
    use_learning_rate_finder = False,
)
# Out:
# [I 2024-04-20 09:09:51,883] A new study created in memory with name: no-name-66907382-8180-4321-9f7b-4ec37f44d143
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:13:09,422] Trial 0 finished with value: 157.9573211669922 and parameters: {'gradient_clip_val': 0.29136218560427096, 'hidden_size': 26, 'dropout': 0.2857762475488046, 'hidden_continuous_size': 4, 'attention_head_size': 4, 'learning_rate': 0.004740929068502099}. Best is trial 0 with value: 157.9573211669922.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:16:15,519] Trial 1 finished with value: 175.38088989257812 and parameters: {'gradient_clip_val': 0.013101789399169207, 'hidden_size': 22, 'dropout': 0.13537369433436924, 'hidden_continuous_size': 1, 'attention_head_size': 1, 'learning_rate': 0.012208195523958652}. Best is trial 0 with value: 157.9573211669922.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:19:31,147] Trial 2 finished with value: 159.22311401367188 and parameters: {'gradient_clip_val': 0.41269917969399095, 'hidden_size': 11, 'dropout': 0.2983761322682106, 'hidden_continuous_size': 4, 'attention_head_size': 4, 'learning_rate': 0.0021127630255039186}. Best is trial 0 with value: 157.9573211669922.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [I 2024-04-20 09:20:41,184] Trial 3 finished with value: 185.1505584716797 and parameters: {'gradient_clip_val': 0.07530900286645993, 'hidden_size': 10, 'dropout': 0.28114451314223154, 'hidden_continuous_size': 3, 'attention_head_size': 3, 'learning_rate': 0.003982904813632737}. Best is trial 0 with value: 157.9573211669922.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:23:53,277] Trial 4 finished with value: 155.74205017089844 and parameters: {'gradient_clip_val': 0.048793265247342496, 'hidden_size': 16, 'dropout': 0.1486850239485754, 'hidden_continuous_size': 4, 'attention_head_size': 3, 'learning_rate': 0.009677843009616936}. Best is trial 4 with value: 155.74205017089844.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:26:59,464] Trial 5 finished with value: 170.02207946777344 and parameters: {'gradient_clip_val': 0.5016281556406857, 'hidden_size': 20, 'dropout': 0.2311114561476795, 'hidden_continuous_size': 1, 'attention_head_size': 1, 'learning_rate': 0.01191096524074811}. Best is trial 4 with value: 155.74205017089844.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:30:09,531] Trial 6 finished with value: 176.44651794433594 and parameters: {'gradient_clip_val': 0.018916929031164657, 'hidden_size': 17, 'dropout': 0.13600484443641267, 'hidden_continuous_size': 2, 'attention_head_size': 2, 'learning_rate': 0.020829995088176127}. Best is trial 4 with value: 155.74205017089844.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:33:20,394] Trial 7 finished with value: 175.22930908203125 and parameters: {'gradient_clip_val': 0.012647761871002094, 'hidden_size': 26, 'dropout': 0.21837599433733346, 'hidden_continuous_size': 1, 'attention_head_size': 4, 'learning_rate': 0.0017040135448037667}. Best is trial 4 with value: 155.74205017089844.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:36:33,688] Trial 8 finished with value: 159.42579650878906 and parameters: {'gradient_clip_val': 0.10654518659287783, 'hidden_size': 10, 'dropout': 0.12365981170972265, 'hidden_continuous_size': 4, 'attention_head_size': 2, 'learning_rate': 0.0011757318184241635}. Best is trial 4 with value: 155.74205017089844.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:39:53,003] Trial 9 finished with value: 171.70823669433594 and parameters: {'gradient_clip_val': 0.907918352903938, 'hidden_size': 89, 'dropout': 0.18120727948946866, 'hidden_continuous_size': 2, 'attention_head_size': 4, 'learning_rate': 0.03171045612006779}. Best is trial 4 with value: 155.74205017089844.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:43:04,169] Trial 10 finished with value: 175.07859802246094 and parameters: {'gradient_clip_val': 0.04802442771770188, 'hidden_size': 46, 'dropout': 0.17056511652549533, 'hidden_continuous_size': 2, 'attention_head_size': 3, 'learning_rate': 0.088356330967281}. Best is trial 4 with value: 155.74205017089844.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:46:18,677] Trial 11 finished with value: 161.5972137451172 and parameters: {'gradient_clip_val': 0.17288877489053664, 'hidden_size': 39, 'dropout': 0.2566243980296218, 'hidden_continuous_size': 3, 'attention_head_size': 3, 'learning_rate': 0.005229528597723778}. Best is trial 4 with value: 155.74205017089844.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:49:33,238] Trial 12 finished with value: 170.3479461669922 and parameters: {'gradient_clip_val': 0.1911518022947972, 'hidden_size': 15, 'dropout': 0.25315309894217447, 'hidden_continuous_size': 4, 'attention_head_size': 4, 'learning_rate': 0.006873205131089888}. Best is trial 4 with value: 155.74205017089844.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:52:45,989] Trial 13 finished with value: 151.32571411132812 and parameters: {'gradient_clip_val': 0.02634748178178561, 'hidden_size': 30, 'dropout': 0.1873134264973365, 'hidden_continuous_size': 3, 'attention_head_size': 3, 'learning_rate': 0.003456136527340227}. Best is trial 13 with value: 151.32571411132812.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:55:54,760] Trial 14 finished with value: 150.51637268066406 and parameters: {'gradient_clip_val': 0.03178875719024878, 'hidden_size': 8, 'dropout': 0.10469022211987455, 'hidden_continuous_size': 3, 'attention_head_size': 2, 'learning_rate': 0.0031558694168128663}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 09:59:07,376] Trial 15 finished with value: 162.0936737060547 and parameters: {'gradient_clip_val': 0.02637493341948369, 'hidden_size': 9, 'dropout': 0.10598173241035695, 'hidden_continuous_size': 3, 'attention_head_size': 2, 'learning_rate': 0.0026613879154319784}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 10:02:15,960] Trial 16 finished with value: 170.3293914794922 and parameters: {'gradient_clip_val': 0.030614811735776522, 'hidden_size': 8, 'dropout': 0.10601784977529256, 'hidden_continuous_size': 2, 'attention_head_size': 2, 'learning_rate': 0.0010073443884500083}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 10:05:28,042] Trial 17 finished with value: 159.57199096679688 and parameters: {'gradient_clip_val': 0.025619173181463624, 'hidden_size': 34, 'dropout': 0.189148227426019, 'hidden_continuous_size': 3, 'attention_head_size': 1, 'learning_rate': 0.0035218050421569687}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 10:08:37,459] Trial 18 finished with value: 251.4789581298828 and parameters: {'gradient_clip_val': 0.010797143000591418, 'hidden_size': 62, 'dropout': 0.1554280634603992, 'hidden_continuous_size': 2, 'attention_head_size': 2, 'learning_rate': 0.00272569793829922}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 10:11:50,637] Trial 19 finished with value: 160.20779418945312 and parameters: {'gradient_clip_val': 0.046313370484360614, 'hidden_size': 14, 'dropout': 0.20435488658438647, 'hidden_continuous_size': 3, 'attention_head_size': 3, 'learning_rate': 0.001507450306929586}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 10:15:17,874] Trial 20 finished with value: 216.1534423828125 and parameters: {'gradient_clip_val': 0.01750068665457032, 'hidden_size': 126, 'dropout': 0.16962018332613207, 'hidden_continuous_size': 1, 'attention_head_size': 2, 'learning_rate': 0.002203184418124094}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 10:18:28,393] Trial 21 finished with value: 163.33143615722656 and parameters: {'gradient_clip_val': 0.04419078650285242, 'hidden_size': 16, 'dropout': 0.1526813119720466, 'hidden_continuous_size': 4, 'attention_head_size': 3, 'learning_rate': 0.007405133220967712}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 10:21:36,746] Trial 22 finished with value: 159.12509155273438 and parameters: {'gradient_clip_val': 0.06771470130047104, 'hidden_size': 12, 'dropout': 0.10242898036489942, 'hidden_continuous_size': 3, 'attention_head_size': 3, 'learning_rate': 0.0035482121774462272}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# [I 2024-04-20 10:24:49,067] Trial 23 finished with value: 156.0865478515625 and parameters: {'gradient_clip_val': 0.034707637445500865, 'hidden_size': 13, 'dropout': 0.12451780089874802, 'hidden_continuous_size': 4, 'attention_head_size': 3, 'learning_rate': 0.00779760405359344}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [I 2024-04-20 10:26:26,881] Trial 24 finished with value: 154.56809997558594 and parameters: {'gradient_clip_val': 0.020570082078020063, 'hidden_size': 19, 'dropout': 0.15782904628608654, 'hidden_continuous_size': 3, 'attention_head_size': 3, 'learning_rate': 0.00535927610498345}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [I 2024-04-20 10:26:53,966] Trial 25 finished with value: 230.593017578125 and parameters: {'gradient_clip_val': 0.01983186234982668, 'hidden_size': 8, 'dropout': 0.19782731921202615, 'hidden_continuous_size': 2, 'attention_head_size': 2, 'learning_rate': 0.004802455403409952}. Best is trial 14 with value: 150.51637268066406.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
with open('test_study.pkl', 'wb') as fout:
    pickle.dump(study, fout)

print(study.best_trial.params)

# %%
# !pip install optuna-integration

# %%
# !pip install --no-cache --force optuna==3.4.0

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
